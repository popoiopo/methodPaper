# %%
import researchhelper as rh
import matplotlib.pyplot as plt
import numpy as np

a = np.linspace(0,1,100)
fig, ax = plt.subplots(1,1,figsize=(8,10))
ax.plot(a,a,label="testing")
plt.show()

# %%
fig, ax = plt.subplots(1,1,figsize=(8,10))
ax.plot(a,a,label="testing")
rh.visualize.setStandardFrame(ax)
rh.visualize.setLabelsAndTitles(ax, "title", "x-axis", "y-axis")
rh.visualize.setLegend(ax, loc=2)
plt.show()
